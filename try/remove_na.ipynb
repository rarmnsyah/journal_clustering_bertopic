# %%
import pandas as pd

# %%
dataset = pd.read_csv('dataset/articles.csv', sep = '|')
dataset = dataset.drop(columns = ['Unnamed: 0'])
dataset
# Out:
#           jid                                       aid        date  \
# 0       10015       oai:ojs2.jrpb.unram.ac.id:article/1   TIDAK ADA
# 1       10015       oai:ojs2.jrpb.unram.ac.id:article/4   TIDAK ADA
# 2       10015       oai:ojs2.jrpb.unram.ac.id:article/6   TIDAK ADA
# 3       10015       oai:ojs2.jrpb.unram.ac.id:article/8  2015-03-01
# 4       10015       oai:ojs2.jrpb.unram.ac.id:article/9   TIDAK ADA
# ...       ...                                       ...         ...
# 670398   9994  oai:ojs.jurnal.unpad.ic.id:article/21238  2019-04-05
# 670399   9994  oai:ojs.jurnal.unpad.ic.id:article/16985  2018-06-06
# 670400   9994  oai:ojs.jurnal.unpad.ic.id:article/11954  2017-03-21
# 670401   9994  oai:ojs.jurnal.unpad.ic.id:article/10358  2016-11-30
# 670402   9994  oai:ojs.jurnal.unpad.ic.id:article/28765  2020-07-23
#
#                                                     title  \
# 0                                               TIDAK ADA
# ...

# %%
cp_dataset = dataset.copy()

# %%
dataset.query("desc == 'TIDAK ADA'")
# Out:
#           jid                                       aid        date  \
# 0       10015       oai:ojs2.jrpb.unram.ac.id:article/1   TIDAK ADA
# 1       10015       oai:ojs2.jrpb.unram.ac.id:article/4   TIDAK ADA
# 2       10015       oai:ojs2.jrpb.unram.ac.id:article/6   TIDAK ADA
# 3       10015       oai:ojs2.jrpb.unram.ac.id:article/8  2015-03-01
# 4       10015       oai:ojs2.jrpb.unram.ac.id:article/9   TIDAK ADA
# ...       ...                                       ...         ...
# 670223   9994  oai:oai.jurnal.unpad.ac.id:article/13425   TIDAK ADA
# 670224   9994   oai:oai.jurnal.unpad.ac.id:article/5429   TIDAK ADA
# 670225   9994   oai:www.jurnal.unpad.ac.id:article/2117   TIDAK ADA
# 670308   9994  oai:oai.jurnal.unpad.ac.id:article/13961   TIDAK ADA
# 670386   9994  oai:oai.jurnal.unpad.ac.id:article/10364   TIDAK ADA
#
#             title       desc
# 0       TIDAK ADA  TIDAK ADA
# 1       TIDAK ADA  TIDAK ADA
# 2       TIDAK ADA  TIDAK ADA
# 3       TIDAK ADA  TIDAK ADA
# ...

# %%
dataset.query("title == 'TIDAK ADA'")
# Out:
#           jid                                       aid        date  \
# 0       10015       oai:ojs2.jrpb.unram.ac.id:article/1   TIDAK ADA
# 1       10015       oai:ojs2.jrpb.unram.ac.id:article/4   TIDAK ADA
# 2       10015       oai:ojs2.jrpb.unram.ac.id:article/6   TIDAK ADA
# 3       10015       oai:ojs2.jrpb.unram.ac.id:article/8  2015-03-01
# 4       10015       oai:ojs2.jrpb.unram.ac.id:article/9   TIDAK ADA
# ...       ...                                       ...         ...
# 670223   9994  oai:oai.jurnal.unpad.ac.id:article/13425   TIDAK ADA
# 670224   9994   oai:oai.jurnal.unpad.ac.id:article/5429   TIDAK ADA
# 670225   9994   oai:www.jurnal.unpad.ac.id:article/2117   TIDAK ADA
# 670308   9994  oai:oai.jurnal.unpad.ac.id:article/13961   TIDAK ADA
# 670386   9994  oai:oai.jurnal.unpad.ac.id:article/10364   TIDAK ADA
#
#             title       desc
# 0       TIDAK ADA  TIDAK ADA
# 1       TIDAK ADA  TIDAK ADA
# 2       TIDAK ADA  TIDAK ADA
# 3       TIDAK ADA  TIDAK ADA
# ...

# %%
bodied_df = dataset.query("desc != 'TIDAK ADA' and title != 'TIDAK ADA'")
bodied_df
# Out:
#           jid                                       aid        date  \
# 28      10015      oai:ojs2.jrpb.unram.ac.id:article/40  2017-07-30
# 29      10015      oai:ojs2.jrpb.unram.ac.id:article/41  2017-07-30
# 31      10015      oai:ojs2.jrpb.unram.ac.id:article/43  2017-07-30
# 32      10015      oai:ojs2.jrpb.unram.ac.id:article/44  2017-07-30
# 34      10015      oai:ojs2.jrpb.unram.ac.id:article/46  2017-07-30
# ...       ...                                       ...         ...
# 670398   9994  oai:ojs.jurnal.unpad.ic.id:article/21238  2019-04-05
# 670399   9994  oai:ojs.jurnal.unpad.ic.id:article/16985  2018-06-06
# 670400   9994  oai:ojs.jurnal.unpad.ic.id:article/11954  2017-03-21
# 670401   9994  oai:ojs.jurnal.unpad.ic.id:article/10358  2016-11-30
# 670402   9994  oai:ojs.jurnal.unpad.ic.id:article/28765  2020-07-23
#
#                                                     title  \
# 28      PERFORMANSI TRAKTOR TANGAN RODA DUA MODIFIKASI...
# ...

# %%
bodied_df.iloc[0]['desc']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 bodied_df.iloc[0]['desc']
#
# NameError: name 'bodied_df' is not defined

# %%
bodied_df.dropna(inplace=True)
bodied_df.to_csv('dataset/bodied_articles.csv', sep = '|')
