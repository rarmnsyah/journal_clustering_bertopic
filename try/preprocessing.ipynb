# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
from text_processing.text_processing import *

import pandas as pd

# %%
dataset = pd.read_csv('../dataset/bodied_articles.csv', sep = '|')
dataset
# Out:
#         Unnamed: 0.1  Unnamed: 0    jid  \
# 0                  0          28  10015
# 1                  1          29  10015
# 2                  2          31  10015
# 3                  3          32  10015
# 4                  4          34  10015
# ...              ...         ...    ...
# 247083        247085      670398   9994
# 247084        247086      670399   9994
# 247085        247087      670400   9994
# 247086        247088      670401   9994
# 247087        247089      670402   9994
#
#                                              aid        date  \
# 0           oai:ojs2.jrpb.unram.ac.id:article/40  2017-07-30
# 1           oai:ojs2.jrpb.unram.ac.id:article/41  2017-07-30
# 2           oai:ojs2.jrpb.unram.ac.id:article/43  2017-07-30
# 3           oai:ojs2.jrpb.unram.ac.id:article/44  2017-07-30
# 4           oai:ojs2.jrpb.unram.ac.id:article/46  2017-07-30
# ...                                          ...         ...
# 247083  oai:ojs.jurnal.unpad.ic.id:article/21238  2019-04-05
# 247084  oai:ojs.jurnal.unpad.ic.id:article/16985  2018-06-06
# 247085  oai:ojs.jurnal.unpad.ic.id:article/11954  2017-03-21
# 247086  oai:ojs.jurnal.unpad.ic.id:article/10358  2016-11-30
# 247087  oai:ojs.jurnal.unpad.ic.id:article/28765  2020-07-23
#
#                                                     title  \
# 0       PERFORMANSI TRAKTOR TANGAN RODA DUA MODIFIKASI...
# 1       ANALISIS KESERAGAMAN ASPEK FERTIGASI PADA DESA...
# 2       RANCANG BANGUN MESIN PENCAMPUR KEDELAI DENGAN ...
# 3       MODEL PENGEMBANGAN USAHA BUDIDAYA RUMPUT LAUT ...
# 4       APLIKASI PROGRAM LINEAR DALAM PEMBUATAN FORMUL...
# ...                                                   ...
# 247083  Hubungan Karakteristik terhadap Tingkat Aktivi...
# 247084  PERSPEKTIF TENAGA KESEHATAN: BUDAYA KESELAMATA...
# 247085  Hubungan Aktivitas Fisik dengan Kadar Kolester...
# 247086  SKRINING THALASSEMIA BETA MINOR PADA SISWA SMA...
# 247087  Gambaran Malnutrisi Pasien Anak Di Ruang Rawat...
#
#                                                      desc
# 0       Tujuan dari penelitian ini adalah untuk melaku...
# 1       Hidroponik merupakan teknologi bercocok tanam ...
# 2       Kekalik Jaya adalah salah satu sentra produksi...
# 3       Pantai Cipatujah Kabupaten Tasikmalaya merupak...
# 4       Tujuan penelitian adalah mempelajari formulasi...
# ...                                                   ...
# 247083  Posyandu merupakan bentuk Upaya Kesehatan Bers...
# 247084  Kejadian Tidak Diharapkan (KTD) yang paling um...
# 247085  Saat ini aktivitas fisik pada masyarakat semak...
# 247086  Jenis Thalassemia yang paling banyak ditemukan...
# 247087  Kondisi malnutrisi pada pasien anak yang menja...
#
# [247088 rows x 7 columns]

# %%
text = dataset['desc'][2]
text
# Out:
# 'Kekalik Jaya adalah salah satu sentra produksi bahan olahan berupa tempe di wilayah Mataram. Pada pengolahannya secara umum masih menggunakan metode tradisional.Proses pembuatan tempe yang memegang bagian penting penentu mutu tempe adalah proses peragian tempe dengan kapang.Kualitas tempe dinilai&nbsp; berdasarkan warna tempe, tingkat kepadatan tempe, sebaran kapang yang tumbuh menyelimuti tempe.Sehingga untuk menjaga nilai mutu tersebut, pencampuran ragi dengan kedelai perlu pengerjaan yang optimal guna menjaga kualitas tempe. Untuk tetap mempertahankan mutu tempe, para produsen perlu untuk diberikan pengenalan teknologi sederhana dalam proses produksi tempe berupa mesin pencampur. Selain usaha tempe, masyarakat Mataram juga menekuni usaha pengrajin besi, yang berada didaerah sandubaya Mataram. Dengan adanya desain alat ini dapat membantu para pengrajin semakin memiliki hubungan yang erat dengan pengusaha tempe sehingga perekonomian Mataram semakin meningkat antar sektor industrinya. Desain mesin ini menggunakan motor sebagai sumber penggerak, sehingga tabung silinder berputar. Tenaga dari motor ditransmisikan ke silinder oleh vanbelt. Silinder berputar dengan kecepatan tertentu, dengan sirip dalam yang mampu membolak-balikkan bahan hingga tercampur rata seiring dengan berputarnya silinder.\nKata kunci: mesin pencampur, rancang bangun, tempe'

# %%
preprocessed_text = preprocess_text(text)
preprocessed_text
# Out:
# 'kekalik jaya adalah salah satu sentra produksi bahan olahan berupa tempe di wilayah mataram pada pengolahannya secara umum masih menggunakan metode tradisionalproses pembuatan tempe yang memegang bagian penting penentu mutu tempe adalah proses peragian tempe dengan kapangkualitas tempe dinilai berdasarkan warna tempe tingkat kepadatan tempe sebaran kapang yang tumbuh menyelimuti tempesehingga untuk menjaga nilai mutu tersebut pencampuran ragi dengan kedelai perlu pengerjaan yang optimal guna menjaga kualitas tempe untuk tetap mempertahankan mutu tempe para produsen perlu untuk diberikan pengenalan teknologi sederhana dalam proses produksi tempe berupa mesin pencampur selain usaha tempe masyarakat mataram juga menekuni usaha pengrajin besi yang berada didaerah sandubaya mataram dengan adanya desain alat ini dapat membantu para pengrajin semakin memiliki hubungan yang erat dengan pengusaha tempe sehingga perekonomian mataram semakin meningkat antar sektor industrinya desain mesin ini menggunakan motor sebagai sumber penggerak sehingga tabung silinder berputar tenaga dari motor ditransmisikan ke silinder oleh vanbelt silinder berputar dengan kecepatan tertentu dengan sirip dalam yang mampu membolakbalikkan bahan hingga tercampur rata seiring dengan berputarnya silinder kata kunci mesin pencampur rancang bangun tempe'
